# %%
print "Hello World"
# Out:
# Hello World

# %% [markdown]
# ##Panda Excercise

# %%
import pandas as pd
import numpy as np
from __future__ import division
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.options.display.mpl_style = 'default'

# %%
header_row = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num',]
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data'
heart_data = pd.read_csv(url, header=0, na_values = '?')
heart_data.columns = header_row

# %%
print heart_data.tail(10)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  num
# 292   63    1   4       140   187    0        2      144      1      4.0      1   2     7    2
# 293   63    0   4       124   197    0        0      136      1      0.0      2   0     3    1
# 294   41    1   2       120   157    0        0      182      0      0.0      1   0     3    0
# 295   59    1   4       164   176    1        2       90      0      1.0      2   2     6    3
# 296   57    0   4       140   241    0        0      123      1      0.2      2   0     7    1
# 297   45    1   1       110   264    0        0      132      0      1.2      2   0     7    1
# 298   68    1   4       144   193    1        0      141      0      3.4      2   2     7    2
# 299   57    1   4       130   131    0        0      115      1      1.2      2   1     7    3
# 300   57    0   2       130   236    0        2      174      0      0.0      2   1     3    1
# 301   38    1   3       138   175    0        0      173      0      0.0      1 NaN     3    0

# %%
print type(heart_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# * Features are columns
# * Observations are rows
# * Taregt variable

# %% [markdown]
# ## DataFrames behave like lists

# %%
## Lists
import random
random_list = [random.random() for i in xrange(300)]

print random_list[3:14]
print random_list[280:]
print random_list[:20]

print len(random_list)

## DataFrame
print heart_data[3:14]
print heart_data[280:]
print heart_data[:20]

print len(heart_data)
# Out:
# [0.45820672689615216, 0.322214831075029, 0.852183376022073, 0.12242170308837919, 0.06674614417334124, 0.4456497094131606, 0.9755177717524555, 0.4492755774003623, 0.9505012030131287, 0.8160887913161258, 0.8760954447018656]
# [0.7209241558220826, 0.24636864925450086, 0.6286702868781395, 0.36053845848580834, 0.8902188561767099, 0.16393457230994501, 0.21590719812302905, 0.35174364609834685, 0.24901383980266734, 0.9656099083174159, 0.7035396937924075, 0.8993351907181966, 0.34802388806998685, 0.9091121042810631, 0.5358655038466553, 0.10165450051150449, 0.6204617276119894, 0.8151159043967423, 0.5692385050543889, 0.09383316165766131]
# [0.7346002202470099, 0.3700887215052069, 0.7848449696692953, 0.45820672689615216, 0.322214831075029, 0.852183376022073, 0.12242170308837919, 0.06674614417334124, 0.4456497094131606, 0.9755177717524555, 0.4492755774003623, 0.9505012030131287, 0.8160887913161258, 0.8760954447018656, 0.5650980800188415, 0.042762669154446264, 0.2713368129099094, 0.3912677328080606, 0.7127165881863107, 0.8821736681640675]
# 300
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  num
# 3    41    0   2       130   204    0        2      172      0      1.4      1   0     3    0
# 4    56    1   2       120   236    0        0      178      0      0.8      1   0     3    0
# 5    62    0   4       140   268    0        2      160      0      3.6      3   2     3    3
# 6    57    0   4       120   354    0        0      163      1      0.6      1   0     3    0
# 7    63    1   4       130   254    0        2      147      0      1.4      2   1     7    2
# 8    53    1   4       140   203    1        2      155      1      3.1      3   0     7    1
# 9    57    1   4       140   192    0        0      148      0      0.4      2   0     6    0
# 10   56    0   2       140   294    0        2      153      0      1.3      2   0     3    0
# 11   56    1   3       130   256    1        2      142      1      0.6      2   1     6    2
# 12   44    1   2       120   263    0        0      173      0      0.0      1   0     7    0
# 13   52    1   3       172   199    1        0      162      0      0.5      1   0     7    0
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  num
#
# 15   48    1   2       110   229    0        0      168      0      1.0      3   0     7    1
# 16   54    1   4       140   239    0        0      160      0      1.2      1   0     3    0
# 17   48    0   3       130   275    0        0      139      0      0.2      1   0     3    0
# 18   49    1   2       130   266    0        0      171      0      0.6      1   0     3    0
# 19   64    1   1       110   211    0        2      144      1      1.8      2   0     3    0
# 302

# %%
## Dictionary
some_dict = {k: [random.random() for i in xrange(20)] for k in ['a', 'b', 'c',]}
some_dict['d'] = [i**2 for i in some_dict['a']]

print some_dict['a']
print some_dict['b']
print [i for i in some_dict['a'] if i > .5]

## DataFrame
heart_data['random_var'] = [random.random() for i in heart_data.index]

print heart_data['age'].head()
print heart_data['sex'].head()
print heart_data[['cp', 'oldpeak']].head()

# Note on Printing Types -- What do we get back?
print type(heart_data['sex'])
print type(heart_data[['sex']])
print type(heart_data[['cp', 'oldpeak']])

# Creating a subset:
# Since random.random uses a flat distribution, consider the below as one approach to pick a random subset.
heart_subset = heart_data[heart_data['random_var'] >.7].head()
# Out:
# [0.8467989154107652, 0.7897954031457155, 0.18261861932252133, 0.005813847739518652, 0.7254590588485178, 0.6877371856442526, 0.44484707735487106, 0.4611095327355039, 0.5017116999601667, 0.5417712356887968, 0.33295114819779315, 0.47819471387721246, 0.10867136950637091, 0.7088092938073828, 0.7018649158187421, 0.07244666646797748, 0.9799001003261598, 0.34052222654729225, 0.593863978812499, 0.5709723779670958]
# [0.15407196351374308, 0.12307436608753597, 0.027892793858221965, 0.021513031691691165, 0.654148778166876, 0.46207831171680747, 0.34970019853080414, 0.9761076655506363, 0.108272599386949, 0.6396849849258499, 0.29313075570414615, 0.5014380441701771, 0.7972984470752303, 0.9137517866445163, 0.01856579020072735, 0.5246935749189614, 0.836033125546649, 0.8265787932062867, 0.9552371728449293, 0.7522134198880455]
# [0.8467989154107652, 0.7897954031457155, 0.7254590588485178, 0.6877371856442526, 0.5017116999601667, 0.5417712356887968, 0.7088092938073828, 0.7018649158187421, 0.9799001003261598, 0.593863978812499, 0.5709723779670958]
# 0    67
# 1    67
# 2    37
# 3    41
# 4    56
# Name: age, dtype: float64
# 0    1
# 1    1
# 2    1
# 3    0
# 4    1
# Name: sex, dtype: float64
#    cp  oldpeak
# 0   4      1.5
# 1   4      2.6
# 2   3      3.5
# 3   2      1.4
# 4   2      0.8
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
print heart_data['chol'].head()
print heart_data[heart_data['thalach'] < 150].head()
print heart_data[heart_data.age > heart_data.age.median()].head()
heart_data[heart_data.cp == 4].describe()
# Out:
# 0    286
# 1    229
# 2    250
# 3    204
# 4    236
# Name: chol, dtype: float64
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal  num  random_var
# 0    67    1   4       160   286    0        2      108      1      1.5      2   3     3    2    0.395599
# 1    67    1   4       120   229    0        2      129      1      2.6      2   2     7    1    0.997177
# 7    63    1   4       130   254    0        2      147      0      1.4      2   1     7    2    0.983061
# 9    57    1   4       140   192    0        0      148      0      0.4      2   0     6    0    0.655701
# 11   56    1   3       130   256    1        2      142      1      0.6      2   1     6    2    0.568589
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  ca  thal