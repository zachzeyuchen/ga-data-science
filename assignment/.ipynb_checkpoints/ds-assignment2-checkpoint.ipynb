# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import seaborn as sns
from __future__ import division
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.options.display.mpl_style = 'default'

# %%
bike_share = pd.read_csv('bikeshare.csv')
bike_share.head(10)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0        1  2011-01-01       1   0     1   0        0        6           0           1  0.24  0.2879  0.81     0.0000       3          13   16
# 1        2  2011-01-01       1   0     1   1        0        6           0           1  0.22  0.2727  0.80     0.0000       8          32   40
# 2        3  2011-01-01       1   0     1   2        0        6           0           1  0.22  0.2727  0.80     0.0000       5          27   32
# 3        4  2011-01-01       1   0     1   3        0        6           0           1  0.24  0.2879  0.75     0.0000       3          10   13
# 4        5  2011-01-01       1   0     1   4        0        6           0           1  0.24  0.2879  0.75     0.0000       0           1    1
# ...

# %% [markdown]
# ## How many people ride hourly and daily?

# %%
sns.set(context = 'notebook', style = 'whitegrid')
# group by the data frame by hr and calculate the hourly average 
bike_hr = bike_share.groupby('hr')
plt.figure(figsize=(20, 8), dpi=200)
plt.xticks(np.arange(0, 24, 1.0))
bike_hr.cnt.mean().plot()
# group by the data frame by day and calculate the daily total
bike_day = bike_share.groupby('dteday')
plt.figure(figsize=(20, 8), dpi=200)
bike_day.cnt.sum().plot()

# %% [markdown]
# ## Visualize the relationships between the ridership and different features

# %%
cols = ['casual','registered', 'hr','season', 'workingday','weathersit',]
pd.scatter_matrix(bike_share[cols], figsize=(12, 12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1177cc250>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a40b410>]], dtype=object)

# %% [markdown]
# ## Summerize the result
# * On an hourly base, there were more people ride during rush hours (8am - 10am, 5pm - 7pm)
# * Throughout 2 years in this dataset, the daily number of riders was increasing. Also, there seems to be a strong seasonality pattern that more poeple tend to rider in spring and summer time and less people ride in winter and fall time.
# * From all the features given, I selected 'hr', 'season', 'workingday' and 'weathersit' to look at beacuse these features seems to be more representative than other simliar features. From the scatter metrix plot we can see that
#     1. more registered users ride during rush hour, while more casual users ride during day time (10am to 5pm).
#     2. 'season' doesn't tell much of a difference between registered and causual.
#     3. 'wordkingday' is a strong indicator that more registered users ride on working days while more casual users ride on non-working days.
#     4. 'weathersit' tells that more registered users tend to ride in bad weathers. Both group tend to ride more on good weather and less in extreme weather.

# %% [markdown]
# ## Business application
# Based on the analysis I had earlier, I would suggest to log bike location and usage data in the future. Since more registered users tend to ride during workdays and rush hours, it will be intertesting to know if we have enough bikes for thoes people during those times. It will be great to have more bikes near metro and train station during workdays and rush hours to make sure registered users have bikes to ride. Also it might be good to have more bikes near landmark sites, parks during day time for causual riders.
